# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df_brooklyn = pd.read_csv('brooklyn.csv')

# %%
df.head(5)
# Out:
#    rental_id  rent  bedrooms  bathrooms  size_sqft  min_to_subway  floor  \
# 0       2869  3600       3.0          2        900              4    1.0
# 1       4318  3900       3.0          2       1000              4    9.0
# 2       6265  2700       2.0          1        900              4    2.0
# 3         24  4900       1.0          1       1216              6    3.0
# 4       9481  3900       0.0          1       1100              3    4.0
#
#    building_age_yrs  no_fee  has_roofdeck  has_washer_dryer  has_doorman  \
# 0                15       1             0                 0            0
# 1                 8       0             0                 0            0
# 2                96       0             0                 0            0
# 3                88       0             0                 0            0
# 4                85       1             0                 0            0
#
#    has_elevator  has_dishwasher  has_patio  has_gym      neighborhood  \
# ...

# %%
x = df[['bedrooms', 'bathrooms', 'size_sqft', 'min_to_subway', 'floor', 'building_age_yrs', 'no_fee', 'has_roofdeck', 'has_washer_dryer', 'has_doorman', 'has_elevator', 'has_dishwasher', 'has_patio', 'has_gym']]

y = df[['rent']]

#split data in train and test set 
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2, random_state=6)


df = pd.DataFrame(df_brooklyn)

x = df[['bedrooms', 'bathrooms', 'size_sqft', 'min_to_subway', 'floor', 'building_age_yrs', 'no_fee', 'has_roofdeck', 'has_washer_dryer', 'has_doorman', 'has_elevator', 'has_dishwasher', 'has_patio', 'has_gym']]

y = df[['rent']]

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2, random_state=6)

#create Linear Regression model and fit the model using x_train and y_train 
mlr = LinearRegression()
mlr.fit(x_train,y_train)

# use the model to predict y-values from x_test
y_predict = mlr.predict(x_test)

#test the model on an individuals apartment, predict their rent
sonny_apartment = [[1, 1, 620, 16, 1, 98, 1, 0, 1, 0, 0, 1, 1, 0]]

predict= mlr.predict(sonny_apartment)
print('Predicted rent : $%.2f' % predict)
# Out:
# Predicted rent : $2059.95

# %% [markdown]
# ### plug in any Brooklyn apartment’s values in mlr.predict and see if you are over or underpaying!
